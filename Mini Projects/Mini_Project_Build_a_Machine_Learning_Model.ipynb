# %% [markdown]
# <a href="https://colab.research.google.com/github/stephenebert/Springboard/blob/main/Mini_Project_Build_a_Machine_Learning_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Note: I've just noticed I accidentally submitted the Unit 20.5 project under Unit 24.1, which I've already completed and passed. Therefore, treat this as intended for Unit 20.5's "Mini Project: Build a Machine Learning Model."
